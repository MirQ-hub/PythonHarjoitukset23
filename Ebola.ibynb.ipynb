# %%
import pandas as pd
df=pd.read_excel(r"c:\Users\OMISTAJA\Downloads\ebola-cases-and-deaths-who-gar-sitrep.xls")
print("Initial dataframe")
df.head()
# Out:
# Initial dataframe
#    Country  Case def.  Total cases  Cases last 21 days  Total deaths  \
# 0   Guinea  Confirmed       3351.0                 0.0        2083.0
# 1   Guinea   Probable        453.0                 NaN         453.0
# 2   Guinea  Suspected          0.0                 NaN           NaN
# 3   Guinea        All       3804.0                 0.0        2536.0
# 4  Liberia  Confirmed       3151.0                 NaN           NaN
#
#   Country Report Date
# 0          2015-12-27
# 1                 NaT
# 2                 NaT
# 3                 NaT
# 4          2015-05-09

# %%
#Check missing values
print("Missing values")
print(df.isnull)
# Out:
# Missing values
# <bound method DataFrame.isnull of                      Country  Case def.  Total cases  Cases last 21 days  \
# 0                     Guinea  Confirmed       3351.0                 0.0
# 1                     Guinea   Probable        453.0                 NaN
# 2                     Guinea  Suspected          0.0                 NaN
# 3                     Guinea        All       3804.0                 0.0
# 4                    Liberia  Confirmed       3151.0                 NaN
# 5                    Liberia   Probable       1879.0                 NaN
# 6                    Liberia  Suspected       5636.0                 NaN
# 7                    Liberia        All      10666.0                 NaN
# 8                   Liberia2  Confirmed          9.0                 0.0
# 9                   Liberia2   Probable          0.0                 NaN
# 10                  Liberia2  Suspected          NaN                 NaN
# ...

# %%
df.dropna(inplace = True)

print(df.to_string())
# Out:
#          Country  Case def.  Total cases  Cases last 21 days  Total deaths Country Report Date
# 0         Guinea  Confirmed       3351.0                 0.0        2083.0          2015-12-27
# 8       Liberia2  Confirmed          9.0                 0.0           3.0          2015-01-03
# 12  Sierra Leone  Confirmed       8704.0                 0.0        3589.0          2015-11-08
